# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5238, 3083, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'a', 'term', 'as', 'term', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.037823
# Nearest to UNK: castille, designations, equinox, emergency, erwin, bikes, patrols, itis,
# Nearest to if: regnum, ius, ethno, barricade, tapped, aas, zooming, hurley,
# Nearest to world: namek, fleet, etymological, pretending, fees, seo, incidents, gunship,
# Nearest to often: creditor, screen, competing, speedy, discounts, safeguards, erinyes, erect,
# Nearest to the: cno, scorn, ega, grains, hazmi, countering, alvarez, fatalism,
# Nearest to people: intensity, mq, impoverishment, potentials, hijacked, motorsports, nmi, game,
# Nearest to first: gripped, kipling, uplift, xxiii, stormed, whittier, eec, bub,
# Nearest to war: trumpeter, boron, visionaries, phidias, fiore, vocalic, sib, redirection,
# Nearest to however: dreamer, interpolation, clarity, ballparks, engraving, frivolity, dail, beck,
# Nearest to years: functionalism, oneida, vuoksi, rensselaer, stretches, servile, sae, eerie,
# Nearest to for: nawab, prostrate, sprawling, centimeter, risking, fable, sieur, leche,
# Nearest to zero: intercultural, embryos, factsheet, choruses, crested, west, adour, temps,
# Nearest to would: epicurean, slideshow, zubrin, skits, penh, tera, expiring, gathering,
# Nearest to be: tod, ripken, chatting, aar, eastbound, senescence, clones, prom,
# Nearest to there: rabi, newline, unknowable, prevention, substances, vinge, dhimma, inevitability,
# Nearest to over: veneto, freas, gretchen, polls, relocate, shellfish, queries, vacations,
# Average loss at step 2000: 4.360554
# Average loss at step 4000: 3.859557
# Average loss at step 6000: 3.784599
# Average loss at step 8000: 3.687771
# Average loss at step 10000: 3.619704
# Nearest to UNK: width, shredded, polished, et, leased, astronomy, jacobite, levee,
# Nearest to if: singular, zooming, terence, cooled, pessoa, summands, yusuf, regnum,
# Nearest to world: fleet, mitrokhin, conscript, vesalius, fees, accountants, namek, pivotal,
# Nearest to often: discounts, sometimes, screen, there, partita, creditor, not, navigated,
# Nearest to the: a, its, his, this, an, their, bourgeoisie, quincy,
# Nearest to people: intensity, nmi, sexagesimal, profiling, outrun, chimp, lundy, acceleration,
# Nearest to first: whittier, audrey, pitching, eec, variability, agape, uplift, in,
# Nearest to war: aids, supplements, simplifying, trumpeter, visionaries, vocalic, boron, repercussions,
# Nearest to however: ballparks, dreamer, tiffany, naia, calculated, joy, savant, engraving,
# Nearest to years: functionalism, oneida, denning, giacomo, genetically, soufriere, impresario, rensselaer,
# Nearest to for: with, of, in, risking, evelyn, after, rudimentary, glorious,
# Nearest to zero: nine, six, eight, five, seven, three, four, two,
# Nearest to would: may, can, hines, skits, to, expiring, ancestors, lili,
# Nearest to be: have, polity, was, clashed, is, raps, not, menagerie,
# Nearest to there: it, they, also, pettigrew, which, often, substances, huron,
# Nearest to over: charge, shellfish, freas, yogurt, font, executing, rafe, bela,
# Average loss at step 12000: 3.603839
# Average loss at step 14000: 3.569623
# Average loss at step 16000: 3.407737
# Average loss at step 18000: 3.455949
# Average loss at step 20000: 3.539456
# Nearest to UNK: et, dreadnought, unknowingly, polished, photographer, isothermal, width, majors,
# Nearest to if: yusuf, though, accentual, zooming, singular, reminding, before, can,
# Nearest to world: fleet, mitrokhin, conscript, vesalius, accountants, knows, mercosur, dryden,
# Nearest to often: sometimes, there, who, also, discounts, partita, gto, screen,
# Nearest to the: its, their, an, his, this, any, buzz, overlook,
# Nearest to people: chimp, lundy, outrun, nmi, qualcomm, chassis, intellectuals, correspondingly,
# Nearest to first: whittier, second, pitching, variability, eec, discordianism, surgeon, shading,
# Nearest to war: supplements, aids, simplifying, vocalic, jacket, trumpeter, tuvalu, helens,
# Nearest to however: but, that, savant, dreamer, and, naia, asterism, calculated,
# Nearest to years: days, functionalism, denning, soufriere, months, oneida, impresario, giacomo,
# Nearest to for: in, of, objectionable, median, paulinus, with, thermochemistry, fable,
# Nearest to zero: six, five, seven, nine, four, eight, three, two,
# Nearest to would: may, can, should, will, could, might, skits, hines,
# Nearest to be: have, by, were, is, was, been, clashed, polity,
# Nearest to there: they, it, he, pettigrew, often, also, huron, which,
# Nearest to over: yogurt, charge, bien, freas, reuben, executing, font, shellfish,
# Average loss at step 22000: 3.501310
# Average loss at step 24000: 3.485175
# Average loss at step 26000: 3.485727
# Average loss at step 28000: 3.478951
# Average loss at step 30000: 3.500182
# Nearest to UNK: wilhelm, subjection, et, polished, nsted, judoka, speculative, clary,
# Nearest to if: when, though, accentual, but, before, however, yusuf, argue,
# Nearest to world: fleet, conscript, pivotal, hall, dryden, punish, mitrokhin, mercosur,
# Nearest to often: sometimes, also, there, generally, usually, discounts, commonly, frequently,
# Nearest to the: their, its, his, deficiencies, a, some, many, withdrawn,
# Nearest to people: outrun, recorder, others, nmi, chimp, lundy, intellectuals, chassis,
# Nearest to first: second, whittier, pitching, next, last, variability, stormed, shading,
# Nearest to war: supplements, aids, vocalic, simplifying, ausgleich, quit, helens, instalments,
# Nearest to however: but, although, that, when, dreamer, though, savant, if,
# Nearest to years: days, months, denning, functionalism, soufriere, swallows, zoroastrian, year,
# Nearest to for: with, of, when, visualization, qassam, glorious, objectionable, incriminating,
# Nearest to zero: five, eight, four, seven, nine, three, six, two,
# Nearest to would: can, may, will, could, should, must, might, to,
# Nearest to be: refer, being, been, is, have, clashed, were, was,
# Nearest to there: they, it, he, often, still, pettigrew, accomplished, we,
# Nearest to over: yogurt, bien, executing, queries, arunachal, charge, rafe, reuben,
# Average loss at step 32000: 3.504746
# Average loss at step 34000: 3.492992
# Average loss at step 36000: 3.458247
# Average loss at step 38000: 3.299803
# Average loss at step 40000: 3.426896
# Nearest to UNK: b, hunt, alnus, d, tgv, vdc, kapp, contentious,
# Nearest to if: when, though, where, bis, rebecca, ergodic, accentual, anthroposophical,
# Nearest to world: enver, concatenation, hall, licence, fleet, onboard, hsuan, hippocampus,
# Nearest to often: sometimes, usually, also, generally, who, frequently, commonly, which,
# Nearest to the: this, a, its, their, his, any, aquino, boasting,
# Nearest to people: chimp, outrun, others, members, nmi, recorder, lundy, students,
# Nearest to first: second, next, last, discordianism, final, shading, third, whittier,
# Nearest to war: supplements, vocalic, instalments, simplifying, ausgleich, aids, sib, fought,
# Nearest to however: but, although, that, dreamer, though, while, germination, where,
# Nearest to years: days, months, genesee, denning, itchy, functionalism, year, baguirmi,
# Nearest to for: visualization, glorious, at, of, in, unanimity, clowns, suisse,
# Nearest to zero: five, seven, six, nine, eight, three, four, two,
# Nearest to would: can, could, will, may, should, must, might, did,
# Nearest to be: been, have, being, refer, are, is, was, were,
# Nearest to there: they, it, still, he, often, usually, accomplished, we,
# Nearest to over: between, bien, yogurt, narrating, vacations, executing, hillbilly, clicks,
# Average loss at step 42000: 3.439643
# Average loss at step 44000: 3.453349
# Average loss at step 46000: 3.451584
# Average loss at step 48000: 3.354540
# Average loss at step 50000: 3.379948
# Nearest to UNK: le, et, wrecking, wormhole, aam, orthogonality, casa, timer,
# Nearest to if: when, though, where, while, although, but, so, before,
# Nearest to world: concatenation, enver, swearing, hall, stoves, aotearoa, scribe, wesleyan,
# Nearest to often: sometimes, usually, generally, also, commonly, frequently, now, which,
# Nearest to the: their, its, starfighter, this, a, his, microcontrollers, deficiencies,
# Nearest to people: men, members, outrun, others, students, chimp, squaw, years,
# Nearest to first: second, last, next, midas, third, final, fourth, canaanites,
# Nearest to war: supplements, vocalic, instalments, aids, kodansha, frf, woodford, ausgleich,
# Nearest to however: but, although, that, though, where, while, when, if,
# Nearest to years: days, months, decades, year, people, genesee, itchy, denning,
# Nearest to for: while, engraving, visualization, against, median, glorious, mainland, restraints,
# Nearest to zero: eight, five, seven, six, nine, four, three, two,
# Nearest to would: will, can, could, may, should, must, might, did,
# Nearest to be: have, been, refer, become, being, is, were, are,
# Nearest to there: they, it, still, he, often, not, usually, oscilloscope,
# Nearest to over: bien, yogurt, on, hillbilly, vacations, between, mistreatment, alden,
# Average loss at step 52000: 3.435369
# Average loss at step 54000: 3.432053
# Average loss at step 56000: 3.435595
# Average loss at step 58000: 3.398495
# Average loss at step 60000: 3.391007
# Nearest to UNK: enzyte, shapes, janeiro, gobi, purists, mediation, koestler, le,
# Nearest to if: when, though, where, bis, since, although, while, before,
# Nearest to world: enver, civil, homeopaths, swearing, hall, context, concatenation, scribe,
# Nearest to often: sometimes, usually, commonly, generally, frequently, also, now, typically,
# Nearest to the: their, its, a, this, hypertext, his, some, each,
# Nearest to people: men, others, members, students, chimp, outrun, lundy, southey,
# Nearest to first: last, second, next, third, only, final, best, morricone,
# Nearest to war: instalments, ausgleich, vocalic, supplements, woodford, aids, frf, xl,
# Nearest to however: but, although, though, that, while, which, and, if,
# Nearest to years: days, months, decades, year, minutes, itchy, genesee, inhabitants,
# Nearest to for: of, although, and, when, engraving, if, in, incriminating,
# Nearest to zero: five, eight, four, six, seven, nine, three, two,
# Nearest to would: will, could, can, may, should, must, might, did,
# Nearest to be: been, refer, have, being, become, was, is, clashed,
# Nearest to there: they, it, still, he, we, now, often, this,
# Nearest to over: between, bien, through, around, shrunk, within, vacations, sped,
# Average loss at step 62000: 3.236524
# Average loss at step 64000: 3.258117
# Average loss at step 66000: 3.397647
# Average loss at step 68000: 3.393066
# Average loss at step 70000: 3.360533
# Nearest to UNK: ller, shapes, waterfront, makeover, linear, salinas, cdc, walpole,
# Nearest to if: when, though, bis, while, where, however, although, because,
# Nearest to world: civil, emperor, hall, enver, stoves, invasion, homeopaths, licence,
# Nearest to often: sometimes, usually, frequently, commonly, generally, also, typically, now,
# Nearest to the: its, their, this, any, a, these, each, some,
# Nearest to people: men, others, members, students, lundy, children, outrun, chimp,
# Nearest to first: last, second, next, third, final, best, fourth, only,
# Nearest to war: instalments, frf, ausgleich, supplements, woodford, fought, sepulchre, aids,
# Nearest to however: but, although, while, though, that, where, if, when,
# Nearest to years: days, months, decades, year, minutes, inhabitants, itchy, times,
# Nearest to for: while, in, incriminating, if, kune, glorious, eph, engraving,
# Nearest to zero: five, four, six, eight, nine, seven, three, two,
# Nearest to would: will, could, can, may, should, must, might, cannot,
# Nearest to be: been, being, become, refer, have, is, were, clashed,
# Nearest to there: they, it, still, we, usually, often, she, he,
# Nearest to over: bien, through, within, around, up, considerable, about, handily,
# Average loss at step 72000: 3.376487
# Average loss at step 74000: 3.348482
# Average loss at step 76000: 3.316478
# Average loss at step 78000: 3.350379
# Average loss at step 80000: 3.380266
# Nearest to UNK: photographer, smith, j, infocom, ccp, kingfisher, inquirer, niccol,
# Nearest to if: when, though, bis, where, since, before, although, because,
# Nearest to world: homeopaths, luria, approximating, licence, manned, dismissal, civil, emperor,
# Nearest to often: sometimes, usually, commonly, frequently, generally, typically, also, mostly,
# Nearest to the: their, its, a, his, this, each, deficiencies, cigarettes,
# Nearest to people: men, members, students, others, children, lundy, persons, women,
# Nearest to first: last, second, next, third, fourth, final, best, only,
# Nearest to war: frf, instalments, ausgleich, wars, fought, aids, supplements, tuvalu,
# Nearest to however: but, although, that, though, where, while, strunk, despite,
# Nearest to years: days, months, decades, year, minutes, times, weeks, itchy,
# Nearest to for: engraving, against, wads, nvidia, suisse, ferroelectric, dissipate, grenadines,
# Nearest to zero: five, seven, eight, six, four, three, nine, u,
# Nearest to would: will, could, can, must, may, should, might, cannot,
# Nearest to be: been, being, have, refer, become, were, are, pfeiffer,
# Nearest to there: they, it, still, he, she, now, we, often,
# Nearest to over: within, around, bien, between, unwarranted, through, about, considerable,
# Average loss at step 82000: 3.406685
# Average loss at step 84000: 3.407835
# Average loss at step 86000: 3.392630
# Average loss at step 88000: 3.353993
# Average loss at step 90000: 3.366870
# Nearest to UNK: warbird, drummer, serbo, prayed, ibrahim, na, epistemic, filler,
# Nearest to if: when, where, though, since, bis, although, before, after,
# Nearest to world: syllable, licence, manned, infect, gulf, warps, dismissal, croatian,
# Nearest to often: sometimes, usually, commonly, frequently, generally, typically, also, now,
# Nearest to the: its, this, any, his, ethyl, a, another, their,
# Nearest to people: men, children, members, students, women, christians, lundy, chadwick,
# Nearest to first: last, second, next, fourth, best, third, original, final,
# Nearest to war: wars, frf, instalments, fought, pompeius, kodansha, ausgleich, jabberwocky,
# Nearest to however: but, although, though, that, since, where, while, strunk,
# Nearest to years: days, months, decades, year, minutes, weeks, hours, centuries,
# Nearest to for: while, against, engraving, of, including, when, schirra, qassam,
# Nearest to zero: five, eight, seven, six, nine, four, three, u,
# Nearest to would: will, could, may, should, must, might, can, did,
# Nearest to be: been, become, refer, have, being, was, is, follicle,
# Nearest to there: they, it, he, still, she, we, now, generally,
# Nearest to over: within, bien, through, around, unwarranted, almost, off, ventricle,
# Average loss at step 92000: 3.398117
# Average loss at step 94000: 3.252907
# Average loss at step 96000: 3.359803
# Average loss at step 98000: 3.237295
# Average loss at step 100000: 3.357137
# Nearest to UNK: holyrood, iud, literally, donegal, imaged, immoral, differentiate, deepening,
# Nearest to if: when, where, though, before, bis, although, since, after,
# Nearest to world: licence, enver, dismissal, somber, aotearoa, syllable, request, concatenation,
# Nearest to often: sometimes, usually, commonly, frequently, generally, typically, widely, now,
# Nearest to the: their, its, his, your, a, her, our, this,
# Nearest to people: men, children, students, women, christians, members, players, fans,
# Nearest to first: last, next, second, third, fourth, final, best, original,
# Nearest to war: wars, frf, fought, kodansha, logarithm, ausgleich, sepulchre, instalments,
# Nearest to however: but, although, though, that, where, especially, and, strunk,
# Nearest to years: days, months, decades, year, hours, minutes, weeks, percent,
# Nearest to for: when, after, qassam, if, without, including, against, during,
# Nearest to zero: five, six, eight, seven, four, nine, three, two,
# Nearest to would: will, could, might, should, must, can, may, did,
# Nearest to be: been, refer, being, become, is, have, are, empiricists,
# Nearest to there: they, it, he, still, we, she, now, often,
# Nearest to over: within, around, through, across, bien, considerable, nearly, almost,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
