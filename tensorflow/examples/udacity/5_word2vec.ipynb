# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5238, 3084, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'term', 'anarchism', 'term', 'of', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.102697
# Nearest to an: meritorious, cession, contingents, historia, persist, constraint, zack, kerosene,
# Nearest to are: centres, barbarians, high, vinod, romana, charlize, trigonometry, nmos,
# Nearest to over: nijmegen, yogurt, implicated, citrus, furniture, inflate, utilise, re,
# Nearest to UNK: bally, draining, topographical, maggie, us, mews, pavia, desperately,
# Nearest to his: zeno, hawala, dreamcast, wolof, figurative, mates, vast, mcpherson,
# Nearest to only: shi, masses, takes, masamune, culbert, hif, sakai, spinoffs,
# Nearest to will: united, pelletier, circumcised, dragoon, chileans, hemi, bolster, ganglion,
# Nearest to its: bac, tensors, mozilla, giancana, danse, romanus, mountain, tia,
# Nearest to nine: accompanies, urchin, partitioning, augusto, bernie, bethel, makeshift, geoff,
# Nearest to four: rewrote, trailer, procol, galley, joh, amicable, fallacies, aspect,
# Nearest to from: mobility, mojito, rib, petersburg, beano, fixation, crt, electronically,
# Nearest to this: subregions, consequentialism, pogo, voicing, vdp, davidian, ralph, honeybees,
# Nearest to such: gutierrez, phytoplankton, guillermo, naci, sepp, basin, analogous, replicator,
# Nearest to often: lemass, wrigley, eitc, cardano, gazpacho, canadiens, clip, escuela,
# Nearest to during: loy, dagesh, abhidhamma, specifies, available, sidelined, apatosaurus, studies,
# Nearest to new: techniques, modification, labyrinths, mirza, dominican, yolk, fruiting, coincident,
# Average loss at step 2000: 4.353183
# Average loss at step 4000: 3.866127
# Average loss at step 6000: 3.787210
# Average loss at step 8000: 3.681280
# Average loss at step 10000: 3.609712
# Nearest to an: cession, warmest, the, lifton, meritorious, enciphered, aaron, freeza,
# Nearest to are: were, is, have, noting, handheld, pileser, was, unsure,
# Nearest to over: citrus, rhee, utilise, yogurt, rover, roaming, nijmegen, ros,
# Nearest to UNK: victoria, camps, orbital, conclusion, de, monoids, tilting, ironworks,
# Nearest to his: their, the, her, s, punishments, its, zeno, kinross,
# Nearest to only: we, ampere, shi, takes, commissioner, masses, cluniac, bounding,
# Nearest to will: can, isometry, would, harmonic, stratification, could, nightmarish, hemi,
# Nearest to its: their, the, tensors, stephane, his, silvanus, differentiates, telecom,
# Nearest to nine: eight, six, five, seven, four, zero, three, two,
# Nearest to four: six, eight, three, five, nine, seven, two, zero,
# Nearest to from: in, into, on, by, fibs, rib, petersburg, tompkins,
# Nearest to this: it, the, a, which, wand, crudely, consulted, duplication,
# Nearest to such: well, sepp, validation, gutierrez, replicator, conquerors, cebu, protector,
# Nearest to often: also, cardano, excellent, figured, it, there, countries, tonsure,
# Nearest to during: dagesh, loy, bulgakov, cane, culminating, abhidhamma, restricting, on,
# Nearest to new: labyrinths, political, coincident, yolk, buggery, clanking, hitter, grouped,
# Average loss at step 12000: 3.604951
# Average loss at step 14000: 3.572383
# Average loss at step 16000: 3.408750
# Average loss at step 18000: 3.455356
# Average loss at step 20000: 3.536922
# Nearest to an: the, warmest, cession, nelson, ahmed, shuffle, hays, einer,
# Nearest to are: were, is, have, was, but, while, daniels, be,
# Nearest to over: invokes, rhee, paperbacks, perpetuated, citrus, couldn, yogurt, mummy,
# Nearest to UNK: gray, individualism, structural, civilian, willem, aspect, kit, garand,
# Nearest to his: their, her, its, kinross, the, punishments, zeno, some,
# Nearest to only: we, shi, always, ampere, crates, bounding, hortense, culbert,
# Nearest to will: can, would, could, may, should, might, to, harmonic,
# Nearest to its: their, the, his, stephane, silvanus, comparing, differentiates, dedicate,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to four: three, five, six, seven, eight, two, nine, zero,
# Nearest to from: into, in, at, after, between, and, since, on,
# Nearest to this: which, it, a, impeller, crudely, the, that, integrates,
# Nearest to such: well, known, sepp, protector, including, validation, konami, safe,
# Nearest to often: also, usually, sometimes, there, who, cardano, excellent, tonsure,
# Nearest to during: after, in, dagesh, culminating, until, on, when, southernmost,
# Nearest to new: political, competitive, clanking, interceptors, nave, hitter, grouped, labyrinths,
# Average loss at step 22000: 3.499889
# Average loss at step 24000: 3.487556
# Average loss at step 26000: 3.479704
# Average loss at step 28000: 3.482337
# Average loss at step 30000: 3.501337
# Nearest to an: nelson, warmest, beltway, cession, gazette, shuffle, contingents, ahmed,
# Nearest to are: were, have, is, include, daniels, while, but, pileser,
# Nearest to over: invokes, prevents, perpetuated, ros, couldn, christo, rhee, chrysler,
# Nearest to UNK: tailed, conducive, de, tilting, beside, classifications, sometimes, et,
# Nearest to his: her, their, its, the, kinross, my, s, crashed,
# Nearest to only: always, we, shi, pesach, no, kan, bounding, eh,
# Nearest to will: would, can, could, may, should, must, cannot, might,
# Nearest to its: their, his, the, silvanus, stephane, her, shooters, differentiates,
# Nearest to nine: eight, seven, six, four, five, three, two, zero,
# Nearest to four: eight, five, three, seven, six, two, nine, zero,
# Nearest to from: into, since, under, on, by, through, in, after,
# Nearest to this: which, it, that, maule, what, wand, there, the,
# Nearest to such: well, known, these, including, some, knossos, ecoregions, described,
# Nearest to often: sometimes, usually, also, generally, there, still, widely, cardano,
# Nearest to during: after, in, until, by, at, dagesh, when, on,
# Nearest to new: political, competitive, particular, labyrinths, market, coincident, clanking, meld,
# Average loss at step 32000: 3.498219
# Average loss at step 34000: 3.493717
# Average loss at step 36000: 3.452416
# Average loss at step 38000: 3.303384
# Average loss at step 40000: 3.425314
# Nearest to an: warmest, nelson, cession, freeza, beltway, contingents, saipan, adding,
# Nearest to are: were, have, is, include, isuzu, including, be, but,
# Nearest to over: invokes, prevents, yogurt, involve, about, paperbacks, chrysler, dates,
# Nearest to UNK: d, hancock, b, spoons, copland, relocating, leaguers, tonsure,
# Nearest to his: their, her, its, the, s, my, whose, ulam,
# Nearest to only: traditionally, we, always, shi, galt, first, lions, espoused,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to its: their, his, the, her, silvanus, eternity, differentiates, persecuting,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to four: six, five, three, seven, eight, two, nine, one,
# Nearest to from: into, in, of, since, between, through, on, for,
# Nearest to this: which, it, the, that, ric, he, wand, a,
# Nearest to such: well, including, these, known, certain, described, regarded, like,
# Nearest to often: usually, sometimes, also, generally, who, still, widely, which,
# Nearest to during: after, until, at, on, in, before, privatize, dagesh,
# Nearest to new: clanking, particular, political, environmental, purposely, nave, seasonal, market,
# Average loss at step 42000: 3.432274
# Average loss at step 44000: 3.452159
# Average loss at step 46000: 3.449605
# Average loss at step 48000: 3.353088
# Average loss at step 50000: 3.385628
# Nearest to an: cession, nelson, warmest, freeza, beltway, subsumed, the, another,
# Nearest to are: were, is, have, be, those, include, being, cdna,
# Nearest to over: off, invokes, chrysler, prevents, about, implicated, involve, ros,
# Nearest to UNK: quantifier, penicillin, consort, lexis, pentastar, agrippa, adsl, de,
# Nearest to his: their, her, its, my, the, s, your, antique,
# Nearest to only: always, traditionally, first, we, actually, wels, appleton, flamsteed,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to its: their, his, the, her, silvanus, comparing, guano, daly,
# Nearest to nine: eight, seven, six, four, three, five, zero, two,
# Nearest to four: six, five, three, seven, eight, nine, two, zero,
# Nearest to from: into, since, in, after, at, through, jury, inventive,
# Nearest to this: which, it, the, he, that, reagent, luxuriant, integrates,
# Nearest to such: well, these, known, including, many, described, certain, regarded,
# Nearest to often: sometimes, usually, generally, also, widely, commonly, still, typically,
# Nearest to during: after, in, until, when, at, under, before, since,
# Nearest to new: political, particular, environmental, seasonal, purposely, great, market, sudden,
# Average loss at step 52000: 3.433965
# Average loss at step 54000: 3.429695
# Average loss at step 56000: 3.439596
# Average loss at step 58000: 3.395612
# Average loss at step 60000: 3.393436
# Nearest to an: warmest, cession, einer, dingo, freeza, subsumed, ahmed, another,
# Nearest to are: were, is, have, including, those, include, but, goldie,
# Nearest to over: about, around, through, invokes, off, into, within, between,
# Nearest to UNK: tudor, aa, debug, collapsing, active, humour, woodrow, reid,
# Nearest to his: her, their, its, my, your, ulam, whose, antique,
# Nearest to only: always, first, actually, traditionally, also, never, cite, appleton,
# Nearest to will: would, could, may, can, must, should, might, cannot,
# Nearest to its: their, his, the, her, fie, independently, comparing, shooters,
# Nearest to nine: eight, six, seven, four, five, three, one, two,
# Nearest to four: six, eight, five, three, seven, nine, two, zero,
# Nearest to from: into, since, in, through, tompkins, fibs, after, notebooks,
# Nearest to this: it, which, that, the, there, some, extremophiles, visor,
# Nearest to such: well, these, including, known, many, having, certain, described,
# Nearest to often: usually, sometimes, generally, also, commonly, now, still, typically,
# Nearest to during: after, until, following, before, in, when, within, although,
# Nearest to new: particular, minimum, seasonal, political, purposely, environmental, cartridge, sudden,
# Average loss at step 62000: 3.235160
# Average loss at step 64000: 3.254260
# Average loss at step 66000: 3.405267
# Average loss at step 68000: 3.395980
# Average loss at step 70000: 3.358085
# Nearest to an: cession, dingo, buckle, muskegon, warmest, freeza, beltway, universalist,
# Nearest to are: were, have, is, while, those, include, including, although,
# Nearest to over: about, around, invokes, prevents, oic, within, propped, americanization,
# Nearest to UNK: quantifier, curls, specials, sforza, macphail, hunan, kabuki, sharif,
# Nearest to his: her, their, its, my, your, the, whose, furies,
# Nearest to only: always, traditionally, actually, first, still, alteration, flamsteed, player,
# Nearest to will: would, can, may, could, should, must, might, cannot,
# Nearest to its: their, his, the, her, silvanus, eternity, fie, my,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to four: six, three, five, seven, eight, two, nine, zero,
# Nearest to from: into, through, after, within, headshot, under, in, peripherals,
# Nearest to this: which, it, the, that, there, some, what, another,
# Nearest to such: well, these, known, including, many, certain, regarded, defined,
# Nearest to often: usually, sometimes, generally, commonly, now, frequently, also, still,
# Nearest to during: after, in, within, before, until, following, since, under,
# Nearest to new: particular, clanking, modern, hitter, hauge, minimum, environmental, philosophicus,
# Average loss at step 72000: 3.370123
# Average loss at step 74000: 3.348747
# Average loss at step 76000: 3.316232
# Average loss at step 78000: 3.351013
# Average loss at step 80000: 3.380200
# Nearest to an: cession, freeza, buckle, linea, laura, ole, subsumed, jorkens,
# Nearest to are: were, is, include, have, being, although, these, including,
# Nearest to over: around, about, invokes, within, oic, into, through, kitzmiller,
# Nearest to UNK: smith, i, godel, wuxia, j, schleicher, tim, reginae,
# Nearest to his: her, their, my, its, your, our, the, antique,
# Nearest to only: always, traditionally, first, appleton, actually, alteration, crates, even,
# Nearest to will: would, can, may, could, should, must, might, cannot,
# Nearest to its: their, his, her, the, eternity, my, auditor, bsa,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to from: through, into, after, within, by, under, between, during,
# Nearest to this: which, it, what, the, another, that, integrates, luxuriant,
# Nearest to such: well, these, known, regarded, certain, including, defined, described,
# Nearest to often: sometimes, usually, generally, commonly, typically, frequently, still, now,
# Nearest to during: after, in, before, when, until, within, following, since,
# Nearest to new: particular, modern, old, seasonal, philosophicus, minimum, boyer, clanking,
# Average loss at step 82000: 3.408372
# Average loss at step 84000: 3.412637
# Average loss at step 86000: 3.391686
# Average loss at step 88000: 3.347790
# Average loss at step 90000: 3.363904
# Nearest to an: freeza, seduction, cession, buckle, another, saipan, warmest, dingo,
# Nearest to are: were, include, is, have, these, nice, including, those,
# Nearest to over: around, about, invokes, prevents, off, within, involve, into,
# Nearest to UNK: juno, consort, ibn, ohms, posited, et, weizenbaum, reid,
# Nearest to his: her, their, my, its, your, our, the, whose,
# Nearest to only: always, actually, appleton, wels, alteration, even, universally, collectively,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to its: their, his, her, the, my, eternity, sideband, further,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to four: five, three, seven, eight, six, two, nine, zero,
# Nearest to from: through, into, within, after, electronically, between, during, under,
# Nearest to this: which, it, the, some, similar, luxuriant, extremophiles, another,
# Nearest to such: well, known, these, certain, regarded, including, defined, described,
# Nearest to often: sometimes, usually, generally, commonly, typically, also, frequently, now,
# Nearest to during: after, before, until, in, at, within, since, through,
# Nearest to new: particular, old, special, lightweight, seasonal, hauge, modern, philosophicus,
# Average loss at step 92000: 3.397865
# Average loss at step 94000: 3.251836
# Average loss at step 96000: 3.356500
# Average loss at step 98000: 3.237041
# Average loss at step 100000: 3.364415
# Nearest to an: another, warmest, buckle, cession, hays, arduous, dhole, freeza,
# Nearest to are: were, have, these, include, although, including, those, exist,
# Nearest to over: around, about, within, prevents, invokes, carbonates, swayed, oic,
# Nearest to UNK: juno, consort, neoliberal, conducive, sung, antecedent, ayman, mithraeum,
# Nearest to his: her, their, my, your, its, our, the, s,
# Nearest to only: always, actually, appleton, wels, even, graphically, quintessence, traditionally,
# Nearest to will: would, must, could, can, should, may, might, cannot,
# Nearest to its: their, his, her, the, eternity, jeannie, ncr, your,
# Nearest to nine: eight, seven, six, four, five, three, two, one,
# Nearest to four: seven, five, six, eight, three, nine, two, zero,
# Nearest to from: through, into, in, between, headshot, peripherals, fibs, affectionate,
# Nearest to this: which, it, another, what, the, he, marcellinus, rss,
# Nearest to such: well, known, these, including, certain, regarded, many, defined,
# Nearest to often: sometimes, usually, generally, typically, commonly, frequently, currently, now,
# Nearest to during: after, before, in, until, following, since, through, at,
# Nearest to new: particular, starting, old, special, seasonal, modern, boyer, mint,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
### method used for generation of one cbow batch ###
# https://discussions.udacity.com/t/assignment-5-general-understanding-of-cbow-vs-skip-gram-model/46393/19

start_index = 0

def generate_cbow_batch(batch_size, context_size):
  batch_size = batch_size * context_window
  global start_index
  assert (context_size + 1) % 2 == 1 # the context for a word should always have even number of elements on each side 
  assert batch_size % (context_size) == 0 # should fail if we cannot fit exactly N contexts in one batch
  
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size / context_size, 1), dtype=np.int32)
  # 0,1,2,3 4,5,6,7
  mid_element = context_size // 2
  for i in range(batch_size // context_size):
    buffer = [None] * context_size
    for j in range(context_size + 1):
      idx = (start_index + j) % len(data)
      mid_element_idx = (start_index + mid_element) % len(data)
      
      if idx < mid_element_idx:
        buffer[j] = data[idx]
      elif idx > mid_element_idx:
        buffer[j-1] = data[idx]
      else:
        labels[i,0] = data[mid_element_idx]
    random.shuffle(buffer)
    for j in range(context_size):
      batch[i*context_size + j] = buffer[j]
    start_index = (start_index + 1) % len(data)
    
  return batch, labels

b_size=20
c_size=4
batch, labels = generate_cbow_batch(batch_size=b_size, context_size=c_size)
for i in range(b_size // (c_size)):
  print ("context for %s:" % reverse_dictionary[labels[i,0]])
  for j in range(c_size):
    print (reverse_dictionary[batch[i*(c_size) + j]])
# Out:
# context for as:
# originated
# anarchism
# term
# a
# context for a:
# of
# term
# originated
# as
# context for term:
# as
# abuse
# of
# a
# context for of:
# first
# a
# term
# abuse
# context for abuse:
# used
# first
# term
# of
# /home/albert/.local/lib/python3.5/site-packages/ipykernel/__main__.py:12: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
### initialization of the graph ###

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
context_window = 4 # How many words to consider left and right
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size * context_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  segments = tf.constant([x // context_window for x in range(batch_size * context_window)])
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  compressed_embeddings = tf.segment_sum(embed, segments) # merging couple of embeded words into one input
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, compressed_embeddings,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
  
  input = [dictionary["anarchism"], dictionary["originated"], dictionary["a"], dictionary["term"]] * batch_size
  
  logits = tf.matmul(compressed_embeddings, tf.transpose(softmax_weights)) + softmax_biases
  y_ = tf.nn.softmax(logits)

# %%
### running of the session ###

num_steps = 100001
debug = False

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print ("Initialized")
  average_loss = 0
  if debug:
      feed_dict = {train_dataset : input}
      _, yy = session.run([logits, y_], feed_dict=feed_dict)
      
      top_k = 8 # number of nearest neighbors
      for i in range(7):
        print ([reverse_dictionary[x] for x in (-yy[i, :]).argsort()[1:top_k+1]])
  else:
      for step in range(num_steps):
        batch_data, batch_labels = generate_cbow_batch(batch_size, context_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
       
        average_loss += l
        if step % 2000 == 0:
          if step > 0:
            average_loss = average_loss / 2000
          # The average loss is an estimate of the loss over the last 2000 batches.
          print ("Average loss at step", step, ":", average_loss)
          average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
          sim = similarity.eval()
          for i in range(valid_size):
            valid_word = reverse_dictionary[valid_examples[i]]
            top_k = 8 # number of nearest neighbors
            nearest = (-sim[i, :]).argsort()[1:top_k+1]
            log = "Nearest to %s:" % valid_word
            for k in range(top_k):
              close_word = reverse_dictionary[nearest[k]]
              log = "%s %s," % (log, close_word)
            print (log)
      final_embeddings = normalized_embeddings.eval()
      
      # feeds the algorithm a context and gets the most probable autocompletion/autocorrection
      feed_dict = {train_dataset : input}
      _, y = session.run([logits, y_], feed_dict=feed_dict)

      top_k = 8 # number of nearest neighbors
      for i in range(7):
        print ([reverse_dictionary[x] for x in (-y[i, :]).argsort()[1:top_k+1]])
# Out:
# Initialized
# Average loss at step 0 : 7.85508155823
# Nearest to more: motors, alfons, professional, bonzos, judd, nichiren, crs, nav,
# Nearest to see: fo, boasted, attach, michaux, diversify, thickly, mishnah, onslaught,
# Nearest to only: toothed, thought, ingalls, puritanism, representations, millennialism, schuler, mergers,
# Nearest to system: nabonidus, purchaser, swabia, dialogues, zs, cost, localised, macrostate,
# Nearest to these: papuan, bunkers, biosynthesis, spokesman, holies, concerti, competes, blockade,
# Nearest to were: abeyance, knocked, mathura, dessau, tasks, reworked, palestinians, unjustified,
# Nearest to has: extrusive, elbows, darpa, kinder, upa, hysteria, articles, kremlin,
# Nearest to with: kom, exclusive, chronological, ulein, plume, cranberries, asphalt, fix,
# Nearest to american: lifeson, drenthe, unauthorised, oneworld, remini, coronary, batteries, sqrat,
# Nearest to into: luck, compelling, frisia, pixel, presses, telemetry, mustaine, rosslyn,
# Nearest to s: uiuc, gilbertese, technically, faber, biotic, icy, ogle, unintelligible,
# Nearest to a: rumoured, kyle, protein, maori, honour, rockefeller, joh, joliet,
# Nearest to during: guangdong, goldwater, reclamation, flies, teach, cylinders, pardo, creationists,
# /home/albert/.local/lib/python3.5/site-packages/ipykernel/__main__.py:12: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# Nearest to i: spades, crescent, gianni, demyelinating, transferable, cuvier, cts, carrot,
# Nearest to it: seamstress, asu, spiritual, buoyancy, gabor, saxophonist, incorporating, valerius,
# Nearest to b: xinhua, tms, compressible, returner, audiobook, phillips, beethoven, uta,
# Average loss at step 2000 : 6.05735378593
# Average loss at step 4000 : 4.1896462847
# Average loss at step 6000 : 4.50731110048
# Average loss at step 8000 : 3.81337745851
# Average loss at step 10000 : 3.72591818655
# Nearest to more: less, rather, most, conflagration, pendleton, identified, fiorello, imams,
# Nearest to see: fugitives, midian, neu, ostrich, analgesics, reappears, roaming, emi,
# Nearest to only: ingalls, breakdowns, circled, dizzy, gholas, lea, millennialism, statehouse,
# Nearest to system: ser, levellers, government, mcmahon, feature, purchaser, iguana, dragoon,
# Nearest to these: other, many, they, several, bitmaps, those, bound, some,
# Nearest to were: are, was, had, be, is, ramone, have, exasperation,
# Nearest to has: had, have, is, was, having, freezing, pledges, procedural,
# Nearest to with: and, mathews, counteracting, of, municipalities, entrepreneurship, userland, modules,
# Nearest to american: rosser, unauthorised, cayley, polygamous, onions, dataset, handset, chairs,
# Nearest to into: lengthy, from, reconsideration, pharyngeal, compelling, adhesive, gotovina, specifier,
# Nearest to s: his, caviar, raman, ohio, backups, seller, cbs, zil,
# Nearest to a: the, an, any, patterns, his, locates, this, ien,
# Nearest to during: in, throughout, aise, before, at, following, when, vestal,
# Nearest to i: ii, keller, gerund, visit, bytecode, iii, regiments, doves,
# Nearest to it: he, this, she, there, bugzilla, floors, what, deficit,
# Nearest to b: d, nader, squeezed, concepts, roving, synonyms, mycoplasma, arpanet,
# Average loss at step 12000 : 4.28738672444
# Average loss at step 14000 : 3.57816239601
# Average loss at step 16000 : 3.68404980022
# Average loss at step 18000 : 3.58196524978
# Average loss at step 20000 : 3.31473029235
# Nearest to more: less, rather, better, larger, very, greater, most, imams,
# Nearest to see: roland, apsu, republika, lusatia, known, fugitives, piccolo, sloping,
# Nearest to only: still, just, cooler, pruning, capacitance, criticized, precocious, lea,
# Nearest to system: systems, browns, gheg, armouries, hauk, mathematically, glow, levellers,
# Nearest to these: some, several, many, various, all, they, there, kinds,
# Nearest to were: are, was, is, invading, cartographic, rasmussen, teleological, being,
# Nearest to has: have, had, is, having, fortunately, procedural, was, contains,
# Nearest to with: between, when, blasting, and, userland, tavistock, including, hindemith,
# Nearest to american: handy, aai, bagoas, featuring, cayley, dua, solent, gladius,
# Nearest to into: through, in, from, pharyngeal, gotovina, lengthy, specifier, sentimental,
# Nearest to s: raman, his, isbn, allafrica, reflective, cassation, cayley, cleric,
# Nearest to a: any, pattie, the, another, dirks, locates, this, silverman,
# Nearest to during: in, throughout, before, since, at, until, after, when,
# Nearest to i: ii, bytecode, we, g, stickers, doves, iii, glassware,
# Nearest to it: he, gyro, this, she, there, bugzilla, buoyancy, saad,
# Nearest to b: d, defying, spooky, corrupt, tim, mandola, seven, nets,
# Average loss at step 22000 : 3.38235597351
# Average loss at step 24000 : 3.40249228585
# Average loss at step 26000 : 3.26163203639
# Average loss at step 28000 : 3.32444976401
# Average loss at step 30000 : 3.27280575001
# Nearest to more: less, rather, better, most, greater, very, larger, fewer,
# Nearest to see: frivolity, rec, myocardial, roach, includes, indefinitely, ahmad, known,
# Nearest to only: always, dizzy, liberals, precipitous, defective, no, until, ought,
# Nearest to system: systems, conciliatory, transcontinental, archaeologist, mcmahon, nissan, glow, levellers,
# Nearest to these: certain, many, several, various, some, all, different, their,
# Nearest to were: are, was, is, being, had, have, erectus, scabbard,
# Nearest to has: had, have, having, fortunately, is, cartographic, was, includes,
# Nearest to with: between, trimming, atl, guild, eyepiece, dessau, scare, hackney,
# Nearest to american: america, damn, experienced, british, liquids, hollow, dives, lunisolar,
# Nearest to into: through, from, within, gotovina, agrarianism, lengthy, emigr, then,
# Nearest to s: whose, aunts, faber, raman, cayley, zombies, cleric, your,
# Nearest to a: the, another, any, pattie, no, rhineland, isosceles, vangelis,
# Nearest to during: throughout, after, before, until, since, following, in, through,
# Nearest to i: g, ii, marconi, fritz, felis, alludes, fiduciary, merits,
# Nearest to it: he, she, this, there, bugzilla, what, gyro, buoyancy,
# Nearest to b: f, forelimbs, d, eight, simplified, luke, nets, fortunately,
# Average loss at step 32000 : 3.25001565385
# Average loss at step 34000 : 3.02730773738
# Average loss at step 36000 : 3.20049024105
# Average loss at step 38000 : 3.17339183819
# Average loss at step 40000 : 3.19444522939
# Nearest to more: less, very, rather, most, fewer, too, larger, better,
# Nearest to see: contains, includes, myocardial, satiric, frivolity, rec, pleaded, devanagari,
# Nearest to only: always, still, offences, transcribe, ought, dizzy, grunge, enniskillen,
# Nearest to system: systems, version, device, archaeologist, transcontinental, program, notation, style,
# Nearest to these: several, various, many, certain, those, some, different, all,
# Nearest to were: are, was, is, had, being, invading, quantifiers, include,
# Nearest to has: had, have, having, includes, contains, is, gives, fortunately,
# Nearest to with: between, blasting, heiden, eyepiece, among, without, userland, forgiven,
# Nearest to american: america, scottish, british, sgh, haunt, australian, americans, damn,
# Nearest to into: within, through, from, across, gotovina, agrarianism, between, dreamer,
# Nearest to s: his, whose, launching, weymouth, ahaziah, oint, contractual, volo,
# Nearest to a: another, any, the, every, each, locates, gianfranco, pattie,
# Nearest to during: throughout, before, in, until, after, at, over, through,
# Nearest to i: ii, g, clutter, gpled, eichmann, ionian, aryabhata, v,
# Nearest to it: he, she, this, there, still, gyro, bugzilla, afi,
# Nearest to b: d, forelimbs, unit, carriages, n, r, rth, f,
# Average loss at step 42000 : 3.18072688723
# Average loss at step 44000 : 3.24513903689
# Average loss at step 46000 : 3.16099027085
# Average loss at step 48000 : 3.15560596639
# Average loss at step 50000 : 3.06280806556
# Nearest to more: less, rather, very, better, larger, fewer, greater, most,
# Nearest to see: includes, allows, contains, shrapnel, tables, devanagari, provides, lusatia,
# Nearest to only: no, still, always, yup, currently, padawan, generally, forseti,
# Nearest to system: systems, absorbs, mouse, version, notation, transcontinental, platt, element,
# Nearest to these: various, some, different, several, certain, many, they, their,
# Nearest to were: are, was, include, is, have, exist, had, remain,
# Nearest to has: had, have, having, contains, is, gives, requires, includes,
# Nearest to with: between, without, heiden, unconsciousness, using, nymphs, eyepiece, towards,
# Nearest to american: british, america, australian, valens, boomed, normans, hollow, internalized,
# Nearest to into: within, from, through, down, across, out, around, kamenev,
# Nearest to s: his, whose, your, cayley, haken, my, launching, raman,
# Nearest to a: the, another, any, every, veritable, pattie, this, wuxia,
# Nearest to during: throughout, before, in, since, after, until, from, despite,
# Nearest to i: g, ii, we, continually, christiane, lobos, ionian, sturgeon,
# Nearest to it: she, he, this, gyro, there, bugzilla, bins, they,
# Nearest to b: d, angry, jeremiah, mcmaster, rth, fowler, devourer, approximations,
# Average loss at step 52000 : 3.08059250557
# Average loss at step 54000 : 3.10845285624
# Average loss at step 56000 : 3.15613713586
# Average loss at step 58000 : 2.92705238467
# Average loss at step 60000 : 3.02800950766
# Nearest to more: less, rather, very, better, greater, larger, most, too,
# Nearest to see: includes, allows, contains, provides, shrapnel, unveils, known, myocardial,
# Nearest to only: always, all, lagoon, still, attorney, generally, offences, no,
# Nearest to system: systems, device, notation, network, sense, mouse, hierarchy, unit,
# Nearest to these: certain, different, various, which, many, diamagnetic, numerous, abide,
# Nearest to were: are, was, is, exist, remain, include, had, became,
# Nearest to has: had, have, having, contains, includes, fortunately, provides, requires,
# Nearest to with: between, without, among, against, while, taunton, userland, consolidating,
# Nearest to american: australian, british, america, english, valens, pornography, canadian, professional,
# Nearest to into: through, usages, saga, ponens, celts, museo, within, chat,
# Nearest to s: whose, his, your, sextus, isbn, weymouth, mediums, biol,
# Nearest to a: another, any, the, amounts, locates, every, this, tenji,
# Nearest to during: throughout, after, in, before, at, since, until, post,
# Nearest to i: ii, g, mair, we, historiographical, christiane, lotta, irvin,
# Nearest to it: he, she, gyro, there, actually, this, what, still,
# Nearest to b: d, c, viewer, quarterbacks, vividly, z, uncountably, naturalised,
# Average loss at step 62000 : 3.07151076812
# Average loss at step 64000 : 3.03718084037
# Average loss at step 66000 : 2.92252860093
# Average loss at step 68000 : 2.95155963731
# Average loss at step 70000 : 2.97197300845
# Nearest to more: less, rather, better, greater, very, quite, fewer, larger,
# Nearest to see: includes, allows, contains, known, include, ki, provides, myocardial,
# Nearest to only: always, garrisoned, singular, no, even, capacitance, offences, actually,
# Nearest to system: systems, device, hierarchy, network, environment, constitution, kapp, company,
# Nearest to these: those, certain, major, various, microstate, different, they, breathy,
# Nearest to were: are, was, include, is, have, do, remain, roping,
# Nearest to has: had, have, having, contains, is, includes, binocular, requires,
# Nearest to with: between, without, amongst, toward, taunton, among, chlamydia, using,
# Nearest to american: british, australian, canadian, english, frey, unomig, german, gary,
# Nearest to into: within, through, across, down, beyond, from, forward, agrarianism,
# Nearest to s: whose, isbn, showroom, gonzales, rebekah, eiji, cayley, foreman,
# Nearest to a: another, the, any, no, every, locates, an, ernie,
# Nearest to during: throughout, after, following, before, until, in, since, at,
# Nearest to i: we, you, ii, vi, g, cancels, tiergarten, k,
# Nearest to it: he, she, this, there, bugzilla, gyro, kashmir, what,
# Nearest to b: d, cara, prewar, rasputin, broadbent, yates, mandola, burglar,
# Average loss at step 72000 : 3.01623436424
# Average loss at step 74000 : 2.99972014445
# Average loss at step 76000 : 2.84517860249
# Average loss at step 78000 : 2.99624246806
# Average loss at step 80000 : 3.007996351
# Nearest to more: less, better, rather, very, greater, quite, most, fewer,
# Nearest to see: consider, includes, but, allows, include, provides, refers, contains,
# Nearest to only: no, even, always, albinism, abyssinia, garrisoned, pantheistic, offences,
# Nearest to system: systems, device, notation, warped, sued, environment, transcontinental, regulation,
# Nearest to these: those, various, types, multiple, numerous, they, scuttled, renal,
# Nearest to were: are, was, is, include, being, remain, been, sideband,
# Nearest to has: had, have, contains, having, requires, is, includes, gives,
# Nearest to with: among, between, without, userland, towards, amongst, taunton, toward,
# Nearest to american: america, australian, british, carolina, canadian, german, french, dakota,
# Nearest to into: within, through, across, from, down, gotovina, towards, beyond,
# Nearest to s: whose, your, disallow, his, my, isbn, banishing, oint,
# Nearest to a: the, another, any, mendelevium, every, hartmann, pattie, itchy,
# Nearest to during: throughout, before, after, until, at, in, within, against,
# Nearest to i: ii, they, marianne, you, iii, mail, kombinate, workplaces,
# Nearest to it: he, she, this, gyro, there, reappearance, moluccas, what,
# Nearest to b: d, forelimbs, mathbf, bum, fram, loew, cara, brabant,
# Average loss at step 82000 : 2.95277342677
# Average loss at step 84000 : 2.86061955446
# Average loss at step 86000 : 2.93648366004
# Average loss at step 88000 : 2.9083163113
# Average loss at step 90000 : 2.93170366549
# Nearest to more: less, rather, very, better, quite, most, fewer, larger,
# Nearest to see: consider, includes, allows, included, stair, rec, provides, but,
# Nearest to only: always, entirely, pantheistic, trevelyan, neutralize, soriano, no, alkmaar,
# Nearest to system: systems, version, committee, environment, transcontinental, method, device, notation,
# Nearest to these: multiple, numerous, several, various, those, which, additional, certain,
# Nearest to were: are, was, is, include, been, being, insure, sofia,
# Nearest to has: had, have, contains, having, requires, includes, provides, represents,
# Nearest to with: between, among, eyepiece, against, including, elbows, fortify, taunton,
# Nearest to american: america, australian, british, french, basque, dutch, european, international,
# Nearest to into: through, across, within, together, onto, in, beyond, down,
# Nearest to s: his, whose, isbn, weymouth, idolized, its, rerio, mixer,
# Nearest to a: another, any, the, every, no, amounts, pattie, gianfranco,
# Nearest to during: throughout, in, after, before, since, despite, around, until,
# Nearest to i: ii, we, iii, you, iv, cummings, v, murdock,
# Nearest to it: she, he, this, gyro, there, hearings, bugzilla, graziani,
# Nearest to b: d, abject, carriages, taipa, wouldn, forelimbs, defying, broadbent,
# Average loss at step 92000 : 2.91362450486
# Average loss at step 94000 : 2.83482556152
# Average loss at step 96000 : 2.91154402521
# Average loss at step 98000 : 2.87419933748
# Average loss at step 100000 : 2.63595061266
# Nearest to more: less, better, rather, quite, larger, fewer, very, greater,
# Nearest to see: consider, include, called, rec, allows, favoring, frivolity, provides,
# Nearest to only: always, no, usually, never, universally, still, entirely, regained,
# Nearest to system: systems, method, version, committee, environment, calculator, hierarchy, imply,
# Nearest to these: multiple, specific, certain, those, numerous, various, different, such,
# Nearest to were: are, was, is, being, shandy, had, have, became,
# Nearest to has: had, have, having, contains, is, represents, gives, creates,
# Nearest to with: between, userland, taunton, among, despite, towards, toward, heiden,
# Nearest to american: english, canadian, irish, australian, german, international, vesta, tallest,
# Nearest to into: through, within, across, down, beyond, onto, off, gotovina,
# Nearest to s: his, whose, gonzales, raman, phillip, your, hasse, cayley,
# Nearest to a: another, the, any, pattie, mendelevium, this, an, zubrin,
# Nearest to during: throughout, in, at, until, despite, after, since, before,
# Nearest to i: ii, g, iii, we, vi, you, marianne, reciprocated,
# Nearest to it: she, he, bugzilla, gyro, this, there, they, buoyancy,
# Nearest to b: d, rewrote, lignite, jeremiah, hohner, heapsort, knighted, ostrich,
# ['individualist', 'and', 'he', 'as', 'also', 'that', 'the', 'of']
# ['individualist', 'and', 'he', 'as', 'also', 'that', 'the', 'of']
# ['individualist', 'and', 'he', 'as', 'also', 'that', 'the', 'of']
# ['individualist', 'and', 'he', 'as', 'also', 'that', 'the', 'of']
# ['individualist', 'and', 'he', 'as', 'also', 'that', 'the', 'of']
# ['individualist', 'and', 'he', 'as', 'also', 'that', 'the', 'of']
# ['individualist', 'and', 'he', 'as', 'also', 'that', 'the', 'of']

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.201380
# Nearest to of: braille, bomber, assembled, apiece, diophantine, sulba, besieged, faithfulness,
# Nearest to these: davey, terminally, colorado, trisomy, pruitt, jazz, venom, interaction,
# Nearest to history: rosh, raided, nutritious, savannas, svenska, archaeopteryx, hydrolysis, sting,
# Nearest to only: nightmare, riigikogu, arbor, maududi, programmed, suffixed, camus, johore,
# Nearest to called: stump, lyotropic, simulator, co, meath, litchfield, canard, trademark,
# Nearest to no: darth, rhyme, kangchenjunga, pellets, ncos, bonds, insurrection, shenzhen,
# Nearest to states: interview, isp, brandy, infestation, delaney, solferino, appending, beard,
# Nearest to their: cecilia, nouns, organization, fantasies, final, curtin, adultery, exhumed,
# Nearest to i: ricardo, detainee, misidentification, merle, simulator, instantaneous, galen, srinagar,
# Nearest to th: philipp, chords, repertory, macphail, groundbreaking, deaf, winch, boosting,
# Nearest to nine: kiln, tips, glazer, arrhenius, cessna, protestantism, decomposers, powerpc,
# Nearest to can: gurmukhi, andrea, peace, degas, tamias, germans, maximise, libyans,
# Nearest to has: machines, caspian, enchantments, bak, sticker, lasts, plate, acheson,
# Nearest to as: ether, supersonic, buying, dosages, succumb, brythonic, markup, official,
# Nearest to with: castlereagh, estimates, wace, ananda, apap, opel, coded, corel,
# Nearest to may: trail, artful, fondly, harlan, licks, pillaging, alus, signify,
# Average loss at step 2000: 4.362958
# Average loss at step 4000: 3.863063
# Average loss at step 6000: 3.783927
# Average loss at step 8000: 3.682530
# Average loss at step 10000: 3.619900
# Nearest to of: in, plasmids, imperfect, for, on, at, and, from,
# Nearest to these: davey, compilation, antwerp, laguna, interaction, conspiracy, dong, stimuli,
# Nearest to history: kayaks, godhead, consolidated, lawlessness, scissors, kidneys, chosenness, dubh,
# Nearest to only: riigikogu, guzman, arbor, camus, altman, gerardus, hiddenstructure, johore,
# Nearest to called: lyotropic, co, largely, simulator, stump, sholom, arabica, see,
# Nearest to no: ddot, kangchenjunga, it, anonymously, encased, res, belgian, ruiz,
# Nearest to states: brandy, interview, selina, leadbelly, ffts, sedimentary, penal, infestation,
# Nearest to their: his, its, incline, the, foray, absolution, sets, factorials,
# Nearest to i: champ, simulator, alpacas, they, aylwin, edgerton, summed, limbo,
# Nearest to th: chords, repertory, macphail, monasteries, woe, polynesian, deaf, integrals,
# Nearest to nine: eight, five, six, seven, four, zero, three, two,
# Nearest to can: could, gurmukhi, may, would, obelix, will, appearance, degas,
# Nearest to has: had, is, was, have, pausanias, babel, plate, komondor,
# Nearest to as: be, by, spee, ousting, supersonic, gorgon, dunant, casual,
# Nearest to with: between, into, by, in, on, from, for, transfusions,
# Nearest to may: would, can, alus, antwerp, quadrature, rabbits, nr, hardback,
# Average loss at step 12000: 3.607472
# Average loss at step 14000: 3.571755
# Average loss at step 16000: 3.409168
# Average loss at step 18000: 3.457620
# Average loss at step 20000: 3.542145
# Nearest to of: for, vickers, perpetually, imperfect, nullify, same, sulba, in,
# Nearest to these: some, several, many, all, dong, davey, those, fantastical,
# Nearest to history: daro, chosenness, kayaks, lawlessness, godhead, consolidated, mara, wily,
# Nearest to only: riigikogu, altman, dfs, afl, match, expressly, guzman, johore,
# Nearest to called: lyotropic, co, see, largely, arabica, accumulate, mossad, sholom,
# Nearest to no: encased, sunnah, antecedents, ruiz, kangchenjunga, ddot, anonymously, tendons,
# Nearest to states: brandy, interview, leadbelly, kingdom, vci, laguna, disordered, dissenters,
# Nearest to their: his, its, the, sets, her, incline, touched, you,
# Nearest to i: ii, depots, champ, foul, she, alpacas, aylwin, mondegreen,
# Nearest to th: macphail, repertory, woe, chords, fertilisation, integrals, bc, complement,
# Nearest to nine: eight, six, seven, four, zero, five, three, two,
# Nearest to can: could, may, would, will, gurmukhi, cannot, must, should,
# Nearest to has: had, have, was, is, irix, babel, requires, perseus,
# Nearest to as: numan, ethnically, supersonic, dunant, subcontinent, in, sj, brythonic,
# Nearest to with: in, between, into, for, by, spc, transfusions, invertebrate,
# Nearest to may: can, would, could, should, will, must, nr, to,
# Average loss at step 22000: 3.505242
# Average loss at step 24000: 3.490034
# Average loss at step 26000: 3.481551
# Average loss at step 28000: 3.483758
# Average loss at step 30000: 3.500928
# Nearest to of: in, from, and, for, plasmids, including, jewish, imperfect,
# Nearest to these: some, several, many, all, those, their, such, are,
# Nearest to history: lawlessness, daro, study, chosenness, representatives, kidneys, artery, mara,
# Nearest to only: riigikogu, altman, afl, johore, stub, hiddenstructure, darkness, dfs,
# Nearest to called: co, used, lyotropic, named, sholom, largely, see, dustin,
# Nearest to no: sunnah, any, antecedents, akhenaten, a, ddot, encased, eudoxus,
# Nearest to states: kingdom, nations, party, dissenters, interview, penal, vci, talk,
# Nearest to their: its, his, the, her, these, our, animator, absolution,
# Nearest to i: ii, champ, she, depots, we, they, foul, alpacas,
# Nearest to th: bc, spouse, validated, macphail, huac, woe, boris, rd,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to has: had, have, was, is, requires, concluding, patrilineal, ausw,
# Nearest to as: supersonic, spee, lemnos, ousting, gorgon, countable, agnesi, in,
# Nearest to with: between, in, against, into, for, when, by, including,
# Nearest to may: can, would, could, will, should, must, might, cannot,
# Average loss at step 32000: 3.500910
# Average loss at step 34000: 3.495179
# Average loss at step 36000: 3.454724
# Average loss at step 38000: 3.299141
# Average loss at step 40000: 3.427840
# Nearest to of: for, in, imperfect, duress, mckenna, plasmids, same, saves,
# Nearest to these: several, some, many, both, those, such, their, all,
# Nearest to history: study, daro, lawlessness, artery, representatives, life, sucks, kidneys,
# Nearest to only: altman, it, but, stub, run, darkness, trilemma, hiddenstructure,
# Nearest to called: used, named, see, lyotropic, mossad, arabica, sholom, ewald,
# Nearest to no: any, sunnah, antecedents, livin, eudoxus, akhenaten, ingenious, transported,
# Nearest to states: kingdom, nations, dissenters, penal, neville, party, fife, organisms,
# Nearest to their: his, its, her, the, these, some, my, them,
# Nearest to i: we, ii, he, she, they, depots, you, champ,
# Nearest to th: bc, rd, kosi, ad, spouse, woe, huac, colspan,
# Nearest to nine: eight, seven, six, four, zero, five, three, one,
# Nearest to can: may, will, could, would, must, should, cannot, might,
# Nearest to has: had, have, is, was, requires, catheter, concluding, having,
# Nearest to as: supersonic, by, sync, hei, be, partaking, spee, lemnos,
# Nearest to with: between, by, when, into, against, cistern, including, lugh,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Average loss at step 42000: 3.438612
# Average loss at step 44000: 3.451988
# Average loss at step 46000: 3.452419
# Average loss at step 48000: 3.353621
# Average loss at step 50000: 3.381206
# Nearest to of: in, and, including, same, fundamental, actual, main, for,
# Nearest to these: some, many, several, both, such, those, their, different,
# Nearest to history: daro, study, period, treacherous, life, cafes, artery, representatives,
# Nearest to only: trilemma, stub, serialized, utilise, until, soot, really, affix,
# Nearest to called: named, used, ewald, known, mossad, lyotropic, pleistocene, musicality,
# Nearest to no: any, sunnah, interactionism, transported, little, livin, she, ingenious,
# Nearest to states: kingdom, nations, dissenters, penal, party, vantaa, vci, talk,
# Nearest to their: its, his, her, the, these, our, both, several,
# Nearest to i: ii, we, you, t, he, saracens, depots, they,
# Nearest to th: one, bc, rd, spouse, ad, four, kosi, three,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to has: had, have, is, was, requires, patrilineal, stifle, reminding,
# Nearest to as: lemnos, supersonic, countable, symmetries, agnesi, is, abercrombie, aedui,
# Nearest to with: between, cimmerian, rags, when, spc, glacier, zaghawa, hyksos,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Average loss at step 52000: 3.436426
# Average loss at step 54000: 3.424179
# Average loss at step 56000: 3.442267
# Average loss at step 58000: 3.394117
# Average loss at step 60000: 3.392293
# Nearest to of: for, in, including, fundamental, like, although, imperfect, same,
# Nearest to these: several, many, some, those, both, such, all, which,
# Nearest to history: study, life, period, geography, politics, list, geographic, sucks,
# Nearest to only: until, really, stub, utilise, completed, suction, hashimoto, always,
# Nearest to called: used, named, ewald, mitterrand, conformist, leroy, zu, known,
# Nearest to no: any, sunnah, transported, little, interactionism, equal, unstated, akhenaten,
# Nearest to states: kingdom, nations, fanpage, organisms, penal, vantaa, boomerangs, party,
# Nearest to their: its, his, her, our, the, them, these, your,
# Nearest to i: ii, we, you, depots, t, viii, they, orthogonality,
# Nearest to th: rd, bc, spouse, ad, four, kosi, six, woe,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to has: had, have, is, was, requires, having, legates, concluding,
# Nearest to as: romani, supersonic, spee, lemnos, denote, benelux, lotharingia, lachlan,
# Nearest to with: between, including, when, physicalism, monosodium, mears, in, cimmerian,
# Nearest to may: can, would, will, could, might, should, must, cannot,
# Average loss at step 62000: 3.242421
# Average loss at step 64000: 3.257088
# Average loss at step 66000: 3.406511
# Average loss at step 68000: 3.394641
# Average loss at step 70000: 3.356694
# Nearest to of: including, for, and, unlock, in, exact, include, nicaraguan,
# Nearest to these: many, some, several, such, those, their, are, all,
# Nearest to history: period, daro, study, list, whitbread, politics, cafes, religion,
# Nearest to only: really, utilise, actually, completed, sanitation, expressly, stub, better,
# Nearest to called: named, used, ewald, mitterrand, referred, leroy, known, conformist,
# Nearest to no: any, sunnah, interactionism, little, there, she, transported, immanuel,
# Nearest to states: nations, kingdom, state, vci, beak, penal, countries, dissenters,
# Nearest to their: its, his, her, the, our, my, these, your,
# Nearest to i: ii, we, you, g, t, depots, he, p,
# Nearest to th: bc, rd, ad, spouse, iadb, kosi, fridtjof, huac,
# Nearest to nine: eight, six, seven, five, four, zero, three, one,
# Nearest to can: may, could, will, would, must, cannot, might, should,
# Nearest to has: had, have, is, was, requires, legates, since, although,
# Nearest to as: supersonic, dunant, when, is, lemnos, paradigms, ios, spee,
# Nearest to with: between, including, lugh, mears, into, physicalism, among, ufc,
# Nearest to may: can, would, will, could, might, must, should, cannot,
# Average loss at step 72000: 3.368111
# Average loss at step 74000: 3.350611
# Average loss at step 76000: 3.314236
# Average loss at step 78000: 3.349373
# Average loss at step 80000: 3.377368
# Nearest to of: including, imperfect, in, spinach, original, nutritional, medicinal, frustrations,
# Nearest to these: several, many, those, some, all, such, both, are,
# Nearest to history: period, study, list, daro, inspection, whitbread, life, director,
# Nearest to only: rebuttals, actually, first, stub, keeshonden, really, expressly, relegation,
# Nearest to called: named, used, referred, leroy, known, mitterrand, ewald, fusional,
# Nearest to no: little, any, sunnah, immanuel, interactionism, akhenaten, realistically, equal,
# Nearest to states: kingdom, nations, countries, state, serbian, beak, vantaa, penal,
# Nearest to their: its, his, her, our, your, my, whose, the,
# Nearest to i: ii, we, you, g, they, t, steeple, stiffness,
# Nearest to th: bc, rd, five, iadb, huac, ad, kosi, garnet,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to can: may, could, will, would, must, cannot, might, should,
# Nearest to has: had, have, is, was, requires, since, having, catheter,
# Nearest to as: agnesi, when, dunant, supersonic, before, lemnos, ousting, after,
# Nearest to with: between, in, among, jewels, when, by, if, ambients,
# Nearest to may: can, could, will, would, might, must, should, cannot,
# Average loss at step 82000: 3.408580
# Average loss at step 84000: 3.410322
# Average loss at step 86000: 3.386544
# Average loss at step 88000: 3.352329
# Average loss at step 90000: 3.367172
# Nearest to of: including, personalized, in, for, same, spirited, spinach, imperfect,
# Nearest to these: several, many, some, are, those, both, all, such,
# Nearest to history: period, list, study, politics, inspection, disciplinary, life, component,
# Nearest to only: actually, therus, no, rebuttals, completed, expressly, still, any,
# Nearest to called: named, used, known, referred, considered, leroy, ewald, mitterrand,
# Nearest to no: little, any, interactionism, realistically, eudoxus, sunnah, equal, only,
# Nearest to states: kingdom, nations, countries, inflection, oppenheimer, us, fanpage, beak,
# Nearest to their: its, his, her, our, whose, your, the, my,
# Nearest to i: ii, we, you, g, viii, orthogonality, they, t,
# Nearest to th: bc, rd, seven, ad, kosi, nd, iadb, one,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to can: may, could, will, must, should, would, cannot, might,
# Nearest to has: had, have, is, requires, was, having, since, stifle,
# Nearest to as: mocking, agnesi, gorgon, dunant, spee, verily, authentic, including,
# Nearest to with: between, by, cimmerian, advises, into, in, jewels, lugh,
# Nearest to may: can, could, would, will, might, must, should, cannot,
# Average loss at step 92000: 3.401157
# Average loss at step 94000: 3.249401
# Average loss at step 96000: 3.354169
# Average loss at step 98000: 3.241642
# Average loss at step 100000: 3.358100
# Nearest to of: in, and, imperfect, including, rags, gave, hamburgers, bilinear,
# Nearest to these: several, some, many, all, those, various, which, both,
# Nearest to history: list, period, study, disciplinary, cafes, whitbread, component, references,
# Nearest to only: actually, really, therus, expressly, any, not, keeshonden, either,
# Nearest to called: named, used, referred, leroy, known, considered, titanic, mitterrand,
# Nearest to no: little, any, interactionism, realistically, sunnah, shearer, eudoxus, ravenna,
# Nearest to states: nations, kingdom, countries, eu, us, traits, inflection, oppenheimer,
# Nearest to their: its, his, her, your, our, the, several, them,
# Nearest to i: ii, we, you, viii, they, t, depots, orthogonality,
# Nearest to th: bc, rd, nd, garnet, iadb, huac, ad, thx,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to can: may, could, will, must, would, should, cannot, might,
# Nearest to has: had, have, is, was, requires, since, having, catheter,
# Nearest to as: like, mocking, when, prev, bashar, dunant, misunderstanding, beyond,
# Nearest to with: between, including, blistering, at, mears, into, advises, to,
# Nearest to may: can, could, would, might, should, will, must, cannot,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
